# %%
import sys
sys.path.insert(0, '..')
import pandas as pd
import numpy as np
import seaborn as sns
from iterstrat.ml_stratifiers import MultilabelStratifiedKFold
from scipy.stats import chisquare, ks_2samp
from config import PREPARED_DATA_PATH, ORDERED_CATEGORIES, UNORDERED_CATEGORIES, CITY, POSITION

# %%
STRATIFY_COL = 'stratify_col'
RANDOM_STATE = 42

# %%
train = pd.read_pickle('../data/prepared/train.pkl')
target = pd.read_pickle('../data/prepared/target.pkl')
test = pd.read_pickle('../data/prepared/test.pkl')

# %%
def stratify_data(df_data, stratify_column_name, stratify_values, stratify_proportions, random_state=None):
    """Stratifies data according to the values and proportions passed in
    Args:
        df_data (DataFrame): source data
        stratify_column_name (str): The name of the single column in the dataframe that holds the data values that will be used to stratify the data
        stratify_values (list of str): A list of all of the potential values for stratifying e.g. "Male, Graduate", "Male, Undergraduate", "Female, Graduate", "Female, Undergraduate"
        stratify_proportions (list of float): A list of numbers representing the desired propotions for stratifying e.g. 0.4, 0.4, 0.2, 0.2, The list values must add up to 1 and must match the number of values in stratify_values
        random_state (int, optional): sets the random_state. Defaults to None.
    Returns:
        DataFrame: a new dataframe based on df_data that has the new proportions represnting the desired strategy for stratifying
    """
    df_stratified = pd.DataFrame(columns = df_data.columns) # Create an empty DataFrame with column names matching df_data

    pos = -1
    for i in range(len(stratify_values)): # iterate over the stratify values (e.g. "Male, Undergraduate" etc.)
        pos += 1
        if pos == len(stratify_values) - 1: 
            ratio_len = len(df_data) - len(df_stratified) # if this is the final iteration make sure we calculate the number of values for the last set such that the return data has the same number of rows as the source data
        else:
            ratio_len = int(len(df_data) * stratify_proportions[i]) # Calculate the number of rows to match the desired proportion

        df_filtered = df_data[df_data[stratify_column_name] == stratify_values[i]] # Filter the source data based on the currently selected stratify value
        df_temp = df_filtered.sample(replace=True, n=ratio_len, random_state=random_state) # Sample the filtered data using the calculated ratio
        
        df_stratified = pd.concat([df_stratified, df_temp]) # Add the sampled / stratified datasets together to produce the final result
        
    return df_stratified # Return the stratified, re-sampled data

# %%
test[STRATIFY_COL] = test[[CITY]].apply(lambda  x:', '.join(map(str, x)), axis=1)
train[STRATIFY_COL] = train[[CITY]].apply(lambda  x:', '.join(map(str, x)), axis=1)

# %%
test_distr = (test.groupby(STRATIFY_COL)[STRATIFY_COL].count() / len(test))
stratify_values = test_distr.index
stratify_proportions = test_distr.tolist()

# %%
(test[CITY] == "Заместитель начальника службы корпоративных коммуникаций").sum()
# Out:
# 0

# %%
(train[CITY] == "Заместитель начальника службы корпоративных коммуникаций").sum()
# Out:
# 0

# %%
print(test[CITY].nunique())
print(train[CITY].nunique())
# Out:
# 816
# 853

# %%
len(set(test[CITY]) ^ set(train[CITY]))
# Out:
# 529

# %%
len(set(test[CITY]) & set(train[CITY]))
# Out:
# 570

# %%
len(set(test[CITY]) | set(train[CITY]))
# Out:
# 1099

# %%
set(test[CITY]) & set(train[CITY])
# Out:
# {'NA',
#  'Абадзехская',
#  'Абакан',
#  'Абинск',
#  'Агроном ',
#  'Адлер',
#  'Азов',
#  'Актау',
#  'Актобе',
#  'Алапаевск',
#  'Алатырь',
#  'Алдан',
#  'Алексин',
#  'Алматы',
#  'Алтай ',
#  'Альметьевск',
#  'Анадырь',
#  'Анапа',
#  'Ангарск',
#  'Анжеро-Судженск',
#  'Апатиты',
#  'Апрелевка',
#  'Арамиль',
#  'Арзамас',
#  'Армавир',
#  'Арсеньев',
#  'Артем',
#  'Архангельск',
#  'Асбест',
#  'Астрахань',
#  'Атырау',
#  'Ачинск',
#  'Багаевская',
#  'Балаково',
#  'Балашиха',
#  'Балашов',
#  'Бангладеш',
#  'Барабинск',
#  'Барда ',
#  'Барнаул',
#  'Батайск',
#  'Батырево',
#  'Безенчук',
#  'Белая Калитва',
#  'Белгород',
#  'Белебей',
#  'Белово',
#  'Белокуриха',
#  'Белорецк',
#  'Белореченск',
#  'Бердск',
#  'Березники',
#  'Березовский ',
#  'Бийск',
#  'Биробиджан',
#  'Бирюч',
#  'Благовещенск ',
#  'Бологое',
#  'Большой Камень',
#  'Бор',
#  'Борзя',
#  'Борисоглебск',
#  'Боровичи',
#  'Братск',
#  'Брянск',
#  'Бугульма',
#  'Бугуруслан',
#  'Буденновск',
#  'Бузулук',
#  'Буй',
#  'Быково ',
#  'Валуйки',
#  'Великие Луки',
#  'Великий Новгород',
#  'Великобритания',
#  'Верхний Уфалей',
#  'Верхняя Пышма',
#  'Видное',
#  'Владивосток',
#  'Владикавказ',
#  'Владимир',
#  'Волгоград',
#  'Волгодонск',
#  'Волжск',
#  'Волжский ',
#  'Вологда',
#  'Волоколамск',
#  'Волосово',
#  'Волхов',
#  'Вольгинский',
#  'Вольск',
#  'Воркута',
#  'Воронеж',
#  'Ворсино ',
#  'Воскресенск',
#  'Воткинск',
#  'Всеволожск',
#  'Выборг',
#  'Выгоничи',
#  'Выкса',
#  'Выселки',
#  'Вышний Волочек',
#  'Вязники',
#  'Вязьма',
#  'Гатчина',
#  'Геленджик',
#  'Георгиевск',
#  'Глазов',
#  'Голицыно',
#  'Гомель',
#  'Горно-Алтайск',
#  'Горячий Ключ',
#  'Грозный',
#  'Грушевская',
#  'Грязи',
#  'Губкин',
#  'Губкинский',
#  'Дагестанские Огни',
#  'Дедовск',
#  'Дербент',
#  'Дзержинск ',
#  'Дзержинский',
#  'Димитровград',
#  'Дмитров',
#  'Днепр ',
#  'Долгопрудный',
#  'Домодедово',
#  'Донецк ',
#  'Донской',
#  'Дорохово ',
#  'Дубна',
#  'Дудинка ',
#  'Дюртюли',
#  'Евпатория',
#  'Егорьевск',
#  'Ейск',
#  'Екатеринбург',
#  'Екатериновка ',
#  'Елабуга',
#  'Елец',
#  'Елизово',
#  'Еманжелинск',
#  'Ессентуки',
#  'Ефремов',
#  'Жезказган',
#  'Железноводск',
#  'Железногорск ',
#  'Железногорск-Илимский',
#  'Железнодорожный ',
#  'Жигулевск',
#  'Жуковский',
#  'Заинск',
#  'Западная Двина',
#  'Заполярный',
#  'Запорожье',
#  'Запрудня ',
#  'Заречный ',
#  'Заринск',
#  'Звенигород',
#  'Зверево',
#  'Зеленогорск ',
#  'Зеленоград',
#  'Зеленодольск ',
#  'Зерноград',
#  'Златоуст',
#  'Иваново ',
#  'Ивантеевка',
#  'Ижевск',
#  'Избербаш',
#  'Иланский',
#  'Ирбит',
#  'Иркутск',
#  'Исилькуль',
#  'Искитим',
#  'Истра',
#  'Ишимбай',
#  'Йошкар-Ола',
#  'Казань',
#  'Калач-на-Дону',
#  'Калининград',
#  'Калуга',
#  'Каменоломни',
#  'Каменск-Уральский',
#  'Каменск-Шахтинский',
#  'Каменское ',
#  'Камень-на-Оби',
#  'Камышин',
#  'Камышлов',
#  'Каневская',
#  'Канск',
#  'Караганда',
#  'Карачаевск',
#  'Карпинск',
#  'Касимов',
#  'Каспийск',
#  'Качканар',
#  'Кашира',
#  'Кемерово',
#  'Керчь',
#  'Киев',
#  'Киевское ',
#  'Кингисепп',
#  'Кинель',
#  'Кинешма',
#  'Киржач',
#  'Кириши',
#  'Киров ',
#  'Кирово-Чепецк',
#  'Кировоград',
#  'Кировск ',
#  'Киселевск',
#  'Кисловодск',
#  'Климовск ',
#  'Клин',
#  'Клинцы',
#  'Ковдор',
#  'Ковров',
#  'Когалым',
#  'Коломна',
#  'Колпино',
#  'Кольчугино',
#  'Коммунар',
#  'Комсомольск-на-Амуре',
#  'Конаково',
#  'Кондопога',
#  'Конышевка',
#  'Копейск',
#  'Кореновск',
#  'Коркино',
#  'Королев',
#  'Короча',
#  'Коряжма',
#  'Костанай',
#  'Костомукша',
#  'Кострома',
#  'Котельники',
#  'Котельниково',
#  'Котлас',
#  'Красная Поляна ',
#  'Красноармейск ',
#  'Красногорск',
#  'Краснодар',
#  'Краснознаменск ',
#  'Краснотурьинск',
#  'Красноярск',
#  'Кременчуг',
#  'Кривой Рог',
#  'Кропоткин',
#  'Крымск',
#  'Кстово',
#  'Кузнецк',
#  'Кулебаки',
#  'Кунгур',
#  'Курган',
#  'Курганинск',
#  'Курск ',
#  'Курчатов',
#  'Кызыл',
#  'Кызылорда',
#  'Кыштым',
#  'Лабинск',
#  'Лабытнанги',
#  'Лазаревское',
#  'Лангепас',
#  'Лебедянь',
#  'Ленинградская станица',
#  'Лениногорск',
#  'Ленинск-Кузнецкий',
#  'Лесной Городок',
#  'Лесосибирск',
#  'Ливны',
#  'Липецк',
#  'Лиски',
#  'Лобня',
#  'Лодейное Поле',
#  'Ломоносов',
#  'Лосино-Петровский',
#  'Луганск',
#  'Луховицы',
#  'Лыткарино',
#  'Львов',
#  'Люберцы',
#  'Магадан',
#  'Магнитогорск',
#  'Майкоп',
#  'Малаховка ',
#  'Малая Вишера',
#  'Малоярославец',
#  'Мариинск',
#  'Маркс',
#  'Махачкала',
#  'Мегион',
#  'Междуреченск',
#  'Мелеуз',
#  'Менделеевск',
#  'Миасс',
#  'Микунь',
#  'Миллерово',
#  'Минеральные Воды',
#  'Минск',
#  'Мирный ',
#  'Мичуринск',
#  'Могоча',
#  'Можайск',
#  'Мончегорск',
#  'Морозовск',
#  'Моршанск',
#  'Моршин',
#  'Москва',
#  'Московский',
#  'Муравленко',
#  'Мурино',
#  'Мурманск',
#  'Муром',
#  'Мыски',
#  'Мытищи',
#  'Набережные Челны',
#  'Надым',
#  'Назарово',
#  'Назрань',
#  'Нальчик',
#  'Наро-Фоминск',
#  'Нарьян-Мар',
#  'Нахабино',
#  'Находка',
#  'Невинномысск',
#  'Невьянск',
#  'Нерехта',
#  'Нерюнгри',
#  'Нефтекамск',
#  'Нефтеюганск',
#  'Нижневартовск',
#  'Нижнекамск',
#  'Нижний Новгород',
#  'Нижний Тагил',
#  'Нижняя Тура',
#  'Никель ',
#  'Николаев',
#  'Никольское',
#  'Новая Адыгея',
#  'Новая Чара',
#  'Новоалтайск',
#  'Нововоронеж',
#  'Новокузнецк',
#  'Новокуйбышевск',
#  'Новомихайловский',
#  'Новомосковск ',
#  'Новороссийск',
#  'Новосибирск',
#  'Новотроицк ',
#  'Новоульяновск',
#  'Новоуральск',
#  'Новочебоксарск',
#  'Новочеркасск',
#  'Новошахтинск',
#  'Новый Порт',
#  'Новый Уренгой',
#  'Ногинск',
#  'Норильск',
#  'Ноябрьск',
#  'Нур-Султан',
#  'Нягань',
#  'Обнинск',
#  'Обухово',
#  'Обь',
#  'Овруч',
#  'Одесса',
#  'Одинцово',
#  'Октябрьск',
#  'Октябрьский ',
#  'Оленегорск',
#  'Омск',
#  'Орел',
#  'Оренбург',
#  'Орехово-Зуево',
#  'Орск',
#  'Острогожск',
#  'Отрадное',
#  'Отрадный ',
#  'Оха',
#  'Очер',
#  'Павлово',
#  'Павловский Посад',
#  'Павлодар',
#  'Пенза',
#  'Первоуральск',
#  'Переславль-Залесский',
#  'Пермь',
#  'Петров Вал',
#  'Петрозаводск',
#  'Петропавловск',
#  'Петропавловск-Камчатский',
#  'Печора',
#  'Подольск ',
#  'Подпорожье',
#  'Покачи',
#  'Покров',
#  'Полевской',
#  'Полтава',
#  'Полярные Зори',
#  'Полярный',
#  'Поныри',
#  'Приютово',
#  'Прокопьевск',
#  'Прохоровка',
#  'Псков',
#  'Пушкин',
#  'Пушкино ',
#  'Пыть-Ях',
#  'Пятигорск',
#  'Раздольное ',
#  'Раменское',
#  'Реж',
#  'Реутов',
#  'Ржев',
#  'Россошь',
#  'Ростов ',
#  'Ростов-на-Дону',
#  'Рубцовск',
#  'Руза',
#  'Рыбинск',
#  'Рыбное',
#  'Рязань',
#  'Сабетта ',
#  'Салават',
#  'Салехард',
#  'Сальск',
#  'Самара',
#  'Санкт-Петербург',
#  'Саранск',
#  'Сарапул',
#  'Саратов',
#  'Саров',
#  'Сатка',
#  'Свободный',
#  'Севастополь',
#  'Северобайкальск',
#  'Северодвинск',
#  'Североморск',
#  'Североуральск',
#  'Северск ',
#  'Семилуки',
#  'Сергач',
#  'Сергиев Посад',
#  'Серов',
#  'Серпухов',
#  'Симферополь',
#  'Славянка ',
#  'Славянск-на-Кубани',
#  'Слюдянка',
#  'Смоленск',
#  'Снежинск',
#  'Собинка',
#  'Соликамск',
#  'Солнечногорск',
#  'Соль-Илецк',
#  'Сорочинск',
#  'Сосновоборск',
#  'Сосновый Бор',
#  'Сосногорск',
#  'Софьино ',
#  'Сочи',
#  'Средняя Ахтуба',
#  'Ставрополь',
#  'Староминская',
#  'Старый Оскол',
#  'Стерлитамак',
#  'Стрежевой',
#  'Струнино',
#  'Ступино',
#  'Суджа',
#  'Сумы',
#  'Сургут',
#  'Сухой Лог',
#  'Сызрань',
#  'Сыктывкар',
#  'Таганрог',
#  'Таджикистан',
#  'Тайга',
#  'Тайшет',
#  'Талица',
#  'Тамань',
#  'Тамбов',
#  'Тараз',
#  'Татарск',
#  'Ташкент',
#  'Ташла',
#  'Таштагол',
#  'Тверь',
#  'Тейково',
#  'Темрюк',
#  'Тимашевск',
#  'Тихвин',
#  'Тихорецк',
#  'Тобольск',
#  'Тольятти',
#  'Томилино',
#  'Томск',
#  'Топки',
#  'Торжок',
#  'Тосно',
#  'Троицк ',
#  'Туапсе',
#  'Туймазы',
#  'Тула',
#  'Тулун',
#  'Тында',
#  'Тюмень',
#  'Углич',
#  'Удомля',
#  'Улан-Удэ',
#  'Ульяновск',
#  'Уральск',
#  'Урюпинск',
#  'Усинск',
#  'Усмань',
#  'Усолье-Сибирское',
#  'Уссурийск',
#  'Усть-Илимск',
#  'Усть-Каменогорск',
#  'Усть-Кут',
#  'Усть-Лабинск',
#  'Уфа',
#  'Ухта',
#  'Фрязино',
#  'Хабаровск',
#  'Ханты-Мансийск',
#  'Харьков',
#  'Хасавюрт',
#  'Херсон',
#  'Химки',
#  'Хмельницкий',
#  'Холмск',
#  'Цимлянск',
#  'Чайковский',
#  'Чебаркуль',
#  'Чебоксары',
#  'Челябинск',
#  'Черемхово',
#  'Череповец',
#  'Черкесск',
#  'Черлак ',
#  'Черногорск',
#  'Чернушка',
#  'Чехов',
#  'Чита',
#  'Чудово',
#  'Чусовой',
#  'Шадринск',
#  'Шатура',
#  'Шахты',
#  'Шебекино',
#  'Шишкин Лес',
#  'Шумиха',
#  'Шуя',
#  'Шымкент',
#  'Щелково',
#  'Щербинка',
#  'Электросталь',
#  'Электроугли',
#  'Элиста',
#  'Энгельс',
#  'Югорск',
#  'Южно-Сахалинск',
#  'Юрга',
#  'Якутск',
#  'Ялта',
#  'Ялуторовск',
#  'Ярославль',
#  'Ярцево'}

# %%
len(set(test[POSITION]) ^ set(train[POSITION]))
# Out:
# 19102

# %%
len(set(test[POSITION]) | set(train[POSITION]))
# Out:
# 22318

# %%
len(set(test[POSITION]) & set(train[POSITION]))
# Out:
# 3216

# %%
set(test[POSITION]) ^ set(train[POSITION])
# Out:
# {'Ведущий (региональный) специалист по обороту алкоголя, алкогольному декларированию и ЕГАИС',
#  'Заместитель начальника службы корпоративных коммуникаций',
#  'Business Valuation Analyst',
#  'Инженер-конструктор, ведущий инженер-конструктор',
#  'Главный менеджер по развитию ОРККП',
#  'Начальник отдела мотивации и бизнес-планирования',
#  'Стилист Jo Malone',
#  'Менеджер по работе с бизнес клиентами',
#  'Менеджер строительных проектов',
#  'Специалист СЭБ отдела по работе с просроченной задолженностью',
#  'Специалист ВЭД',
#  'Младший специалист отдела по подбору персонала (рекрутер)',
#  'Механик - наладчик',
#  'C&B manager / HR- аналитик/ Менеджер по компенсациям и льготам Службы HR-эффективности Округа',
#  'Администратор локальной сети',
#  'Старший менеджер отдела отдела сбыта',
#  'Координатор по торговому оборудованию',
#  'Монтажник шпд',
#  'Менеджер по оформлению кредитов',
#  'Ведущий инженер по закачке рабочего агента в пласт цеха подготовки перекачки нефти и газового конденсата',
#  'Юрист суброгационной группы (юрист по взысканию).',
#  'Инспектор транспортной безопасности 3-го класса',
#  'Супервайзер по операционной деятельности филиала',
#  'Младший супервайзер',
#  'Начальник отдела систем промышленной автоматизации',
#  'Руководитель отдела "Служба безопасности"',
#  'ЭКСПЕРТ  КЛИЕНТСКОГО СЕРВИСА',
#  'Менеджер по удержанию ключевых клиентов',
#  'Руководитель отдела развития бизнеса',
#  'Ведущий инженер - энергетик службы Главного энергетика',
#  'Менеджер по управлению категориями (Fresh)',
#  'Руководитель направления продаж сегмент B2B',
#  'Social media customer support',
#  'Менеджер по развитию партнеров госсектора',
#  'Старший инженер Отдел IT  сопровождения пользователей фронтальных бизнес-систем г. Самара',
#  'Специалист технической поддержки инженеров электросвязи',
#  'Старший координатор по складской и транспортной логистике',
#  'Врач-координатор',
#  'Повар вагона ресторана',
#  'Старший инженер сектора слаботочных систем',
#  'Старший Экономист отдела сопровождения кредитных проектов ( малый и средний бизнес)',
#  'Курьер свободный график',
#  'Младший специалист центра кадровой поддержки',
#  'Оператор газовой станции',
#  'Ведущий аналитик потребительского кредитования',
#  'Зам. Директора юридического департамента (до 01.10.2010 - Начальник отдела правового обеспечения строительства (в подчинении 35 сотрудников).',
#  'Senior QA Automation Engineer / QA Automation Lead / Site Reliability Engineer',
#  'Service Manager( Finance)',
#  'Наставник отдела поддержки клиентов',
#  'Аналитик отдела маркетинга российских товарных и транспортных рынков',
#  'Начальник Отдела мониторинга и контроля качества',
#  'Эксперт по техническому развитию сервисов',
#  'Ведущий специалист отдела сопровождения договоров',
#  'Представитель по обслуживанию пассажиров в бизнес зале / Администратор зала',
#  'Supply Chain logistician',
#  'Trade Marketing EH&S manager',
#  'Главный специалист по работе с просроченной задолженностью',
#  'Грусчик Комплектовщик',
#  'Уборщик территории',
#  'Jr HR Business Partner / HR Manager',
#  'Координатор отдела по управлению торговым персоналом',
#  'Территориальный менеджер по побережью',
#  'Руководитель сектора развития инфраструктуры',
#  'Начальник участка Сигнализации централизации и блокировки',
#  'Инженер материально-технического учёта',
#  'Ассистент офиса',
#  'Электромонтер по обслуживанию устройств Сигнализации, Централизации и Блокировки',
#  'Лаборант химического анализа 4 разряда',
#  'Ведущий менеджер отдела',
#  'Оператор - кассир',
#  'Торговый представитель, менеджер по работе с ключевыми клиентами',
#  'Менеджер по торгам',
#  'Менеджер по интегрированной системе менеджмента',
#  'Ведущий инженер технического отдела, Дальневосточной дирекции тяги',
#  'Специалист по кассовым операциям',
#  'Тренер Службы Прямых Продаж',
#  'Заместитель начальника отдела, менеджер по закупкам',
#  'Специалист отдела логистики и сервиса',
#  'Отдел развития поставщиков',
#  'Старший  клиентский менеджер',
#  'Финансовый контролёр дивизиона',
#  'Директор по операционной деятельности b2c',
#  'Директор гипермаркета ****** Казань 1',
#  'Главный специалист строитель отдела строительного надзора',
#  'Коадовщик',
#  'Главный менеджер-экономист',
#  'Бренд-менедже',
#  'Осмотрщик РПС, Слесарь РПС',
#  'Менеджер ФРОВ',
#  'Српровождающий почтовых отправлений',
#  'Заместитель  руководителя секции',
#  'Специалист дирекции авто-страхования',
#  'Ассистент менеджера по корпоративным продажам',
#  'Электромеханик ремонтно-технологического участка службы сигнализации, централизации и блокировки',
#  'Оператор на машинах контактной сварки',
#  'Советник генерального директора по логистике; Руководитель отдела развития логистических услуг',
#  'Старший специалист клиентской службы',
#  'Инспектор группы кадрового учета',
#  'Автодиагност',
#  'Региональный менеджер по обучению и подбору',
#  'Менеджер цепи поставок',
#  'Администратор проектов Департамента по работе с персоналом',
#  'Мобильный оператор',
#  'Киномеханик',
#  'повар универсал мясного производства',
#  'Специалист по охране труда дивизиона Север',
#  'Ведущий менеджер Отдела управления каналами продаж',
#  'IT Product Owner',
#  'Ведущий специалист по таможенным проектам',
#  'Экономист по планированию',
#  'Дежурный специалист технической поддержки (1 линия)',
#  'Клиентский менеджер (малый бизнес)',
#  'Инженер- строитель по техническому надзору',
#  'Инструктор бригады подготовки и открытия ПБО',
#  'Менеджер проектирования и согласования перепланировок',
#  'Оператор выписки документов',
#  'ОПЕРАТОР ПО ОБРАБОТКЕ БАЗ ДАННЫХ',
#  'Менеджер по работе с партнерами и клиентами',
#  'Водетил',
#  'Кредитный специалист группы продаж',
#  'Специалист группы оперативной поддержки клиентов',
#  'Junior Risk Specialist',
#  'Руководитель производства',
#  'Менеджер службы',
#  'Организатор продаж отдела продаж малому бизнесу',
#  'Руководитель направления по развитию системы непрерывных улучшений БРД',
#  'Руководитель отдела по учёту материальных ценностей',
#  'Старший менеджер по развитию бренда работодателя',
#  'Руководитель направления обучения и профессионального развития',
#  'Инженер по монтажу технологического трубопровода',
#  'QA Backend Automation Engineer',
#  'Менеджер по оформлению документов',
#  'Консультант по банковской продукции',
#  'Специалист приема и размещения товара, специалист склада',
#  'Оператор ПМ, сотрудник ресторана, кассир, продавец-консультант',
#  'KAS - Специалист по работе с ключевыми клиентами (диабет-контроль)',
#  'Электромонтер линейных сооружений связи и радиофикации 6 разряда',
#  'Руководитель  отдела логистики и склад (директор филиала)',
#  'Управляющий директор Private banking',
#  'Помощник юриста судебно-правового отдела',
#  'Практикант Управления корпоративного банковского страхования',
#  'Руководитель департамента по развитию корпоративного бизнеса Макрорегиона Юг',
#  'Штукатур маляр',
#  'Супервайзер активного канала',
#  'Контроликонтролер',
#  'Заместитель командира по технической части - главный инженер',
#  'Инженер активного оборудования, ИО начальника 1-го участка',
#  'Инженер по разработке (****** Здоровье)',
#  'Директор отдела корпоративных продаж',
#  'Инженер по глинистым растворам третьей категории',
#  'мастер отдела логистики по погрузке не габаритных и габаритных деталей турбин на жд и авто транспорт',
#  'Распиловщик ЛДСП',
#  'Клиентский менеджер по обслуживанию юридических лиц',
#  'Работник ПБО, Работник бригады подготовки к открытию',
#  'Менеджер по добыче нефти и газа',
#  'Менеджер по продажам сегмента премиум',
#  'Стажер производственного отдела',
#  'Lead UX Developer',
#  'Менеджер по работе с агентами',
#  'Руководитель проекта развития корпоративных клиентов',
#  'Специалист отдела экономической безопасности',
#  'Оператор 1C отдела логистики',
#  'Ведуший специалист-эксперт',
#  'Ведущий специалист отдела учета и сопровождения бизнеса',
#  'Эксперт по сертификации',
#  'Отдел сохранения клиентов',
#  'Региональный логист',
#  'Руководитель Универсального ККО',
#  'Территориальный представитель по торговому маркетингу канала сбыта HoReCa',
#  'Ведущий менеджер-технолог',
#  'Regional Sales Trainer',
#  'Управляющий по прямым продажам',
#  'Сервисно-ремонтная',
#  'Ведущий специалист управления по работе с контрактами и бюджетом ИТ',
#  'Руководитель центра выдачи займов',
#  'Оператор склада, приемщик',
#  'Эксперт КИПиА',
#  'Инженер техобслуживания интерьеров',
#  'Авиационный механник',
#  'Электромеханик КТСМ',
#  'Работник озеленения',
#  'Web программист',
#  'Специалист по обработке клиентской документации',
#  'Специалист по логистике и контролю склада',
#  'Специалист по интернет заказам',
#  'Менеджер по бюджетным продажам (без поиска клиентов )',
#  'Ведущий специалист по работе с проблемной задолженностью (выездной сбор)',
#  'Главный эксперт по управленческой отчетности',
#  'Начальник центра мониторинга качества обслуживания',
#  'Менеджер по онлайн привлечению клиентов  малого бизнеса',
#  'Руководитель группы контроля и качества работы ОПС',
#  'Руководитель отдела по предотвращению внештатных ситуаций',
#  'Мастер - приемщик (слесарный сервис)',
#  'Менеджер по обслуживанию пассажиров: контролер проездных документов',
#  'Среднее образование',
#  'Инженер АТМ',
#  'Ведущий специалист Департамента управления закупками',
#  'Group manager',
#  'Инженер по новой технике и внедрению технологий, - по текущему содержанию пути',
#  'Управляющий по развитию ключевой розницы',
#  'Специалист обработки клиентских запросов',
#  'Продавец кассир продуктов',
#  'Старший разработчик интеграционных решений',
#  'Главный эксперт МСБ',
#  'Младший менеджер проектов',
#  'Начальник цеха контактной сети',
#  'Механик связи',
#  'Консультант отдела развития производственных систем\\Старший консультант службы систем управления производством и маркировкой',
#  'Руководитель группы физической безопасности и  операционного мониторинга Управления экономической безопасности (г.Москва)',
#  'Оператор по сопровождению',
#  'Старший специалист  группы кредитно-финансового контроля.',
#  'Инженер группы дистанционного управления/Командир 9го отсека',
#  'Руководитель отдела документооборота',
#  'Consumer & Market Insights Manager Lead',
#  'Специалист по сопровождению объектов сети',
#  'Диспетчер центра управления сетями',
#  'Начальник склада готовой продукции',
#  'Инженер по организации строительства ЭМР и КИП',
#  'Эксперт СЭБ',
#  'Специалист отдела администрирования компенсаций и договорных отношений',
#  'Руководитель группы маркетинга (группы торгового маркетинга)',
#  'Главный менеджер по работе с автосалонами',
#  'Оператор по обслуживанию корпоративных партнеров группы формализованных заявок',
#  'Руководитель направления MVNO Иркутская область',
#  'Руководитель отдела маркетинговых коммуникаций',
#  'Инженер Технической Поддержки Операторов Связи',
#  'Член рабочей бригады',
#  'Старший операционист, исполняющий обязанности управляющего банковского офиса',
#  'Менеджер отдела сопровождения',
#  'Заместитель руководителя проектов отчетности Департамента финансовой отчетности по МСФО и РСБУ',
#  'Заместитель директора по розничным продажам',
#  'Специалист отдела выплаты',
#  'Специалист отдела сканирования',
#  'Ассистент менеджера по работе с клиентами',
#  'Машинист технологических насосов 5 р.',
#  'Заместитель начальника отдела по эксплуатации',
#  'Начальник линейно-кабельного цеха',
#  'Коммерческий специалист (работа с дистрибьюторами)',
#  'Категорийный аналитик',
#  'Инженер планового отдела',
#  'Специалист поддержки в чатах',
#  'Начальник резерва проводников г.Казань',
#  'Senior brand manager (pet-food)',
#  'Специалист по обслуживанию базовых станций',
#  'Специалист службы расчетов',
#  'менеджер по сторонним перевозкам',
#  'Наладчик сварочных программ и технологического оборудования',
#  'Клиентский менеджер, cib',
#  'Заместитель коммерческого директора Центрального округа',
#  'Стажёр HR проектов',
#  'Дизайнер по упаковке',
#  'Сервисный инженер, продавец, старший кассир',
#  'Супервизор отдела исходящего телемаркетинга',
#  'Машиниста электропоезда',
#  'Руководитель направления по работе с регионами (Аналитик бизнес-процессов), Центр постпродажного обслуживания Департамента логистики и постпродажного обслуживания',
#  'Агент по работе с клиентами',
#  'Водитель с торговым представителем',
#  'Выездной Клиентский менеджер',
#  'Специалист службы обслуживания юридических лиц',
#  'Менеджер по кадровому делопроизводству',
#  'Менеджер по развитию клиентских сегментов',
#  'Менеджер по закупкам. Направление ключевых закупок для мобильной сети и информационных технологий.',
#  'Электромонтер по ремонту и обслуживанию электрооборудования и воздушных линий электропередач.',
#  'Менеджер по благотворительным проектам',
#  'Бухгалтер по учёту ломбардной деятельности',
#  'трубопроводчик линейный 3 разряда',
#  'Заместитель управляющего магазином /Товаровед',
#  'Руководитель отдела корпоративных медиа и соцсетей',
#  'Engineer 1 category',
#  'Секретарь группы организационного обеспечения и документооборота Департамента клиентского сервиса',
#  'Главный менеджер управления по работе с крупными проектами',
#  'Младший аналитик по информационной безопасности',
#  'Менеджер по привлечению клиентов 1 категории',
#  'Руководитель отдела транспортной логистики',
#  'Территориальный управляющий сервисными центрами',
#  'Кладовщик размещения',
#  'начальник управления внешних связей',
#  'Продавец-консультант автомобилей с пробегом',
#  'Специалист по обеспечению пожарной безопасности и охраны труда',
#  'Руководитель отдела оптовых продаж',
#  'Руководитель направления коммуникаций и событийных проектов',
#  'Оператор письменной поддержки пользователей в чате',
#  'Ведущий специалист по системам обработки багажа',
#  'Инспектор по контролю за деятельностью заказчика.',
#  'Продавец-касси, администратор',
#  'Оператор линии упаковки',
#  'Монтажник ТТ -слесарь',
#  'Специалист по таргетированной рекламе (social paid)',
#  'Заместитель начальника департамента',
#  'Продавец-кассир, заместитель директора, менеджер по интернет заказам',
#  'Заместитель начальника отдела учета МПЗ',
#  'Менеджер отдела кадров',
#  'Ведущий специалист группы организации продаж',
#  'Специалист по выкупу автомобилей',
#  'Ведущий менеджер работе с бизнесом',
#  'Специалист по промышленной безопасности 3 категории',
#  'Заместитель управляющего по корпоративному бизнесу',
#  'Специалист группы по доставке розничных продуктов.',
#  'Инженер САПР',
#  'Управляющий распределительного центра',
#  'Менеджер, Директор магазина',
#  'HR Administrator',
#  'Оператор 3й категории',
#  'Шеф-кондитер',
#  'Специалист отдела отчётности и аналитики',
#  'Инженер по организации и нормированию труда , документовед архива, специалист по управлению персонала',
#  'Водитель пс',
#  'Главный специалист группы грузовых и почтовых перевозок',
#  'Ведущий специалист отдела контроля торговых операций',
#  'Инженер по монтажу и тестированию телекоммуникационного оборудования',
#  'Инженер центра автоматизированной системы управления войсками соединения',
#  'Заместитель регионального управляющего',
#  'Руководитель направления  Управление международного комплаенса',
#  'Ведущий инженер КИП и А',
#  'Специалист по сервису консультант',
#  'Начальник отзыв',
#  'Старший менеджер- операционист',
#  'Старший специалист по сопровождению юридических лиц группы поддержки корпоративных клиентов',
#  'Вальцовщик сырья и полуфабрикатов',
#  'Менеджер по развитию операционного лизинга',
#  'Диспетчеретчер транспортного отдела',
#  'Геолог-аналитик',
#  'Ведущий специалист эксперт правового отдела',
#  'Руководитель группы по работе с ключевыми клиентами разливного пива',
#  'Главный специалист службы обслуживания юридических лиц',
#  'Специалист ГУТЗ',
#  'Валерий',
#  'Региональный менеджер (направление кафетерии)',
#  'Менеджер отдела проектов по работе с проблемными активами юридических лиц',
#  'Охранник Контролер',
#  'оператор диспетчерской отгрузки, кладовщик',
#  'Главный специалист сопровождения клиентов',
#  'Торговыйвый представитель',
#  'Продавец- кассир, креативный оформитель торгового зала',
#  'Менеджер по работе с клиентами (выходного дня)',
#  'Помощник машиниста электровоза , тепловоза',
#  'Ст. Контролер',
#  'Специалист по планированию продукта',
#  'Руководитель управления по автоматизации и оптимизации бизнес-процессов',
#  'И.О. Заместителя начальника отдела продаж. Ведущий менеджер отдела корпоративных продаж.',
#  'Оператор ПК (Помощник руководителя)',
#  'Сотрудник внутренней безопасности',
#  'Ведущий инженер по обще-строительным работам / покрытиям, теплоизоляции и огнезащитным работам.',
#  'ведущий экономист бюро сводного анализа и консолидированной отчетности отдела экономического анализа',
#  'Отборщик',
#  'Заместитель директора макро-регионального филиала по B2C',
#  'Специалист консультации и прямых продаж',
#  'Администратор отдела',
#  'Бизнес-аналитик SAP BW',
#  'Посудомоика платят нечего',
#  'Диспетчер координатор',
#  'Заместитель руководителя дополнительным офисом',
#  'Управляющий офиса 1 категории (главный офис в Ростове-на-Дону, прямое подчинение Головному банку).',
#  'Промоутер SAMSUNG',
#  'Старший специалист по развитию и сопровождению',
#  'Менеджер дизайнер',
#  'Сборщик-комплектовщик товара',
#  'Машинист грузового и пассажирского движения',
#  'Начальник отдела анализа и оценки кредитных проектов',
#  'Старший экономист по управлению и учету',
#  'Директор магазина, 2 товароведа и от 4 - до 8 продавцов',
#  'Контролер КГ ОКК',
#  'Руководитель территории продаж и обслуживания',
#  'Директор по качеству сервисов ДИТ',
#  'Руководитель отдела поиска и подбора по России',
#  'Инженер по технической эксплуатации',
#  'Помощник,Персональный водитель Руководителя',
#  'Руководитель направления развития активных продуктов',
#  'МПМ',
#  'Специалист отдела взысканий',
#  'Оператор отгрузки',
#  'Начинающий специалист ( удаленно)',
#  'Клиентский менеджер (ипотечное кредитование)',
#  'ЦИТС Технолог 1 категории сменный',
#  'Бухгалтер (финансовый менеджер)',
#  'Ассистент главного менеджера по закупкам премиум брендов',
#  'Техник предпродажной подготовки',
#  'Старший монтажник',
#  'Консультант, Digital CFO',
#  'Руководитель проектов технического перевооружения',
#  'Ведущий специалист отдела кадров (HR representative)',
#  'Заместитель директора департамента недвижимости',
#  'Оператор ОПС, почта банк',
#  'Главный специалист бэк-офиса',
#  'Руководитель корпоративных проектов',
#  'Специалист по развития территории',
#  'Специалист отдела по обработке клиентских запросов',
#  'Руководитель группы развития производства и закупок',
#  'Категорийный менеджер по закупкам оборудования (головной офис АО "******")',
#  'Head of SEO',
#  'Ведущий кассир отдела резерва',
#  'Контролёр сбора заказов',
#  'Менеджер в управлении продаж ключевым  клиентам Департамента широкопрофильной дистрибуции',
#  'Электромонтёр 4 разряда КС',
#  'Финансовый контролер Подразделение Центрального подчинения Комплаенс',
#  'Начальник сектора по ПБиОТ по УЭТ и УППД',
#  'Ведущий менеджер отдела развития прямых продаж розничный бизнес',
#  'Главный специалист по оценке и контролю бюджета',
#  'Куратор по московской области',
#  'Специалист клиентской группы поддержки',
#  'Начальник службы безопасности ФТС "******"',
#  'Директор В2С',
#  'Пишущий редактор',
#  'Руководитель отдела реализации, сопровождения и взыскания задолженности (рост внутри компании с позиции ведущего экономиста ПЭО)',
#  'Директор по работе с клиентами филиал №7777',
#  'Бригадир операторов самоходных механизмов. Заместитель начальника',
#  'Кредитный инспектор отдела сопровождения кредитных операций малого бизнеса',
#  'Payment and Loyalty Marketing Manager',
#  'Руководитель по привлечению зарплатных проектов и прямых продаж,эквайриг',
#  'Специалист по поддержке продаж автомобилей с пробегом',
#  'Менеджер по партнерским программам',
#  'Инженер по проектированию',
#  'специалист по оценке поддержанных автомобилей',
#  'Старший инженер POS',
#  'Ведущий эксперт по работе с малым бизнесом',
#  'CVM Russia',
#  'Руководитель команды в Agile структуре',
#  'Главный менеджер по внутренним коммуникациям',
#  'Эксперт отдела добывающей промышленности',
#  'Ценный работник',
#  'ИТАЛ',
#  'Business Unit Distribution manager',
#  'Руководитель направления по обеспечению безопасности информации',
#  'Сервис-администратор',
#  'Заместитель руководителя клиентского сервиса',
#  'Мастер по технологии и технологическому оборудованию (ГТРС и УГКС)',
#  'Руководитель подразделения банка',
#  'Аналитик базы данных',
#  'Заместитель директора интернет-магазина',
#  'Старший оператор 1 категории (Группа поддержки бизнеса).',
#  'Инструктор Маникюр',
#  'Менеджер приёма товара',
#  'Старший сервис-менеджер',
#  'Специалист по логистике и интернет заказов',
#  'Младший специалист отдела сопровождения клиентских операций',
#  'Дежурный техник-электрик',
#  'Начальник отдела привлечения клиентов среднего бизнеса',
#  'Слесарь-инструментальщик 4 разряда',
#  'Руководитель направления арендных отношений',
#  'Управляющий торговым центром',
#  'Менеджер по работе с клиентами и складскими операциями',
#  'Специалист SAP',
#  'Помощник бариста',
#  'Руководитель направления привлечения по кредитным продуктам (Средний бизнес)',
#  'Руководитель направления по работе с платежными сервисами и ЦОК',
#  'Главный специалист группы подготовки стандартов',
#  'Продавец, продавец-кассир,',
#  'Старший  аналитик по анализу больших данных',
#  'Руководитель отдела контента и продакшн студии',
#  'Руководитель проектов отдела финансирования доходной недвижимости',
#  'Кассир кассы пересчëта.',
#  'Заместитель руководителя филиала по продажам',
#  'Главный специалист Главного контрольного управления',
#  'Помощник оператора стегального оборудования, комплектовщик, помощник мастера производства',
#  'Региональный представитель в СФО и ДВФО',
#  'Руководитель управления подбора персонала',
#  'руководитель проекта, группа федеральных проектов, отдел по работе с государственными заказчиками/по совместительству комплаенс менеджер',
#  'Контролер по режиму',
#  'специалист центра компетенции по закупкам',
#  'Supply chain activity specialist',
#  'Ведущий визуальный мерчендайзер',
#  'Руководитель центра Стандартизации',
#  'Специалист отдела кадров по совместительству Оператор ПК',
#  'Технический работник',
#  'Менеджер по приему',
#  'Специалист по кадрам; Инженер по нормированию труда 2к.',
#  'Машинист авто-вышки и АГП',
#  'Associate Manager | Management Advisory',
#  'Рентгенолог',
#  'Специалист корпоративного учебного центра',
#  'сотрудник кассовой комнаты',
#  'СтМпт',
#  'ЗДГМ',
#  'Водитель кормовоза',
#  'Ресечер, Менеджер по подбору персонала',
#  'Делопроизво',
#  'Руководитель отдела продуктов',
#  'Старший бухгалтер филиала',
#  'Brand Designer',
#  'Специалист по подбору и пополнению ****** Впрок',
#  'Старший специалист IT отдела (IT service desk senior specialist)',
#  'Водитель-экспедитор медицинской службы',
#  'Младший специалист отдела продаж',
#  'Межрегиональной департамент логистики',
#  'Специалист по обслуживанию физических лиц в цифровых каналах',
#  'Оператор ПК служба доставки',
#  'Старший сотрудник СЭБ',
#  'Тех.переволчик',
#  'Тим лидер',
#  'Руководитель направления по тепловодоснабжению',
#  'Повар заготовка',
#  'По договору подряда',
#  'Старший специалист по возврату просроченной задолженности',
#  'Инспектор верификаци',
#  'Специалист по экспорту',
#  'Продавец-консультант Huawei',
#  '!!!!!!',
#  'Приборист установки производства водорода',
#  'Ведущий специалист функциональная группа управления запасами',
#  'Инспектор отдела безопасности, инспектор отдела по обеспечению бизнеса, специалист видеонаблюдения.',
#  'Старший специалист HelpDesk',
#  'Ученик Оператора ЭВМ',
#  'Инженер Асутп',
#  'Оператор  call-центра',
#  'Специалист по администрированию персонала',
#  'Плиточник-облицовщикв',
#  'Наладчик кулинарного оборудования',
#  'Машинист АГП 7 разряда',
#  'HR, Аналитик учебного центра Сибирского банка',
#  'Помощник системного администратора',
#  'Менеджер по административной поддержке бизнеса',
#  'Логист по собственному транспорту',
#  'Товаровед, продавец.',
#  'Руководитель Торговой точки МТС',
#  'Медицинский представитель ОТС',
#  'Руководитель департамента продуктовой аналитики',
#  'Руководитель развития бизнеса',
#  'Менеджер (заместитель начальника отдела)',
#  '"Слесарь-электрик"',
#  'Комплектовщик,грузчик',
#  'Реставратор',
#  'Руководитель группы закрытия балансов Банка отдела консолидации и контроля баланса Банка Управления обязательной отчетности Департамента учета и отчетности.',
#  'Начальник сектора проектного сопровождения',
#  'Системный администратор, VOIP',
#  'Старший Инженер-Энергетик',
#  'Начальник службы документооборота',
#  'Руководитель отдела по операционной поддержке и регулированию трудовых отношений (3 сотрудника в подчинении)',
#  'Инженер отдела эксплуатации транспортной сети',
#  'Junior SAP consultant MM/SD',
#  'Координатор по медицинскому образованию',
#  'Территориальный управляющий Самарского кластера',
#  'Ведущий инженер, отдела фиксированной сети',
#  'Агент начального обслуживания',
#  'Product operations specialist',
#  'Старший специалист отдела ****** и сопровождения клиентских счетов',
#  'Старший менеджер по логистике( начальник склада)',
#  'Руководитель группы собственных офисов',
#  'Главный менеджер Центра корпоративного страхования',
#  'Специалист по эксплуатации ИС',
#  'Руководитель службы маркетинга по Уральскому округу',
#  'Управляющий магазином Jo Malone London МЕГА Теплый Стан',
#  'Слесарь по обслуживанию тепловых пунктов',
#  'Водитель ПТО',
#  'Кондитер-оформитель',
#  'Заместитель директора филиала, Директор по работе с корпоративными и государственными сегментами Новосибирский филиал',
#  'продавец',
#  'Ведущий специалист отдела обработки хранению документов',
#  'Главный специалист Отдела по работе с состоятельными клиентами',
#  'Инженер приёмки объектов в эксплуатацию, Департамент по эксплуатации',
#  'Руководитель административно-технической группы',
#  'Дкоратор',
#  'Водитель большегрузного транспорта',
#  'Специалист по ОБИ',
#  'Тренер по плаванию, координатор бассейна',
#  'Специалист по приему товара и возврата',
#  'Специалист ОПП 2-категории',
#  'Руководитель отдела грузоподъёмных сооружений и лифтов',
#  'Специалист по вводу информации',
#  'репетитор (английский язык)',
#  'Слесарь-монтажник',
#  'Водитель-курьер,бригадир',
#  'Менеджер по продажам IT услуг',
#  'Стажёр отдела планирования и бюджетирования',
#  'Менеджер по привлечению юридических лиц на РКО',
#  'Ведущий операционист мсб',
#  'Курьер-логист',
#  'Специалист по развитию крупного бизнеса',
#  'Ученик',
#  'Руководитель направления интернет-платежи',
#  'Региональный бизнес-аналитик',
#  'Водитель кара грузчик укладки',
#  'Начальник  отдела пересчета и формирования ценностей ОКУ',
#  'Руководитель группы Трейд-Маркетинга (FMCG: Non Food, Food, Zoo, Beauty)',
#  'Директор отдела по работе с автодилерами',
#  'Завод',
#  'Менеджер по Товару (МПТ)',
#  'Водитель катигория В С Д Е',
#  'Специалист по учету ТМЦ',
#  'инженер сервисной поддержки',
#  'Специалист по информационной поддержке',
#  'Зам директора юридического департамента. Руководитель службы. Региональный директор по реконструкциям',
#  'Младший консультант 1С',
#  'Ведущий аналитик блока риски',
#  'Клиентский менеджер дистанционной поддержки клиентов ипотечного кредитования',
#  'Заместитель директора розничного департамента, член совета директоров',
#  'Менеджер по развитию каналов продаж региона',
#  'Менеджер по продажам на пункте выдачи заказов',
#  'Оператор контролёр кассир',
#  'Менеджер группы продаж по работе с корпоративными клиентами',
#  'Региональный специалист по выкладке товара',
#  'Региональный руководитель направления региона Восток',
#  'Эксперт отдела сопровождения платежей и валютного контроля',
#  'Менеджер отдела оптовых продаж',
#  'Специалист офиса продаж->ио менеджера офиса продаж',
#  'Заведующий производством ресторана',
#  'Стажёр в команде META Marketing',
#  'Касссир',
#  'Руководитель направления партнерских продаж',
#  'Мнеджер по кредитованию физ лиц',
#  'Старший специалист делопроизводства',
#  'Специалист  предотвращения и потерь',
#  'Руководитель группы развития систем поддержки бизнеса, Управление Информационных технологий',
#  'Оператор wireline',
#  'Ведущий эксперт отдела валютного контроля',
#  'Руководитель направления по управлению дебиторской задолженностью (Корпоративный центр, Департамент управления доходами)',
#  'оператор при дежурном по станции',
#  'специалист офисных продаж',
#  'Conversion optimization manager',
#  'Специалист по обработке клиентских заявок корпоративных клиентов',
#  'Специалист по прямым продажам(продажа розничных продуктов банка)',
#  'Ответственный за перемещение денежный отправлений и почтовых отпралений',
#  'Главный специалист (урегулирование убытков ИСЖ, НСЖ, КСЖ, НС)',
#  'Менеждер премиум Центральный офис компании',
#  'Specialist d’achats',
#  'Руководитель развития продаж в отрасли электроэнергетика (с 2020 года)',
#  'Бюджетный контролер (Ведущий/Старший экономист)',
#  'HR Business Partner, Sales SPO1,  Region South',
#  'Главный специалист по обучению и развитию',
#  'Руководитель инновационных проектов',
#  'Наладчик, бригадир',
#  'Специалист отдела веления счетов юридических лиц',
#  'Ассистент судебно-правового отдела',
#  'Менеджер расчетно-кассового узла',
#  'Медицинская сестра палатная',
#  'Специалист отдела ввода данных',
#  'Оператов электронно-вычислительных и вычислительных машин',
#  'Инженер 1 категории Отдел защиты информации',
#  'Специалист выдачи заказов',
#  'Ведущий специалист группа поддержки продаж',
#  'Региональный представитель отдела продаж по УрФО',
#  'Главный специалист отдела продуктов медицинского страхования.',
#  'помошник машиниста.машинист тепловоза.',
#  'Ведущий специалист отдела обработки корреспонденции',
#  'Бизнес-тренер с функцией управления обучением',
#  'Программист-аналитик',
#  'Эксперт-методолог',
#  'Сборщик медицинских препаратов',
#  'Начальник отдела по строительству и запуску магазинов.',
#  'Старший специалист обслуживания клиентов конвергентных услуг',
#  'Логист (закупщик)',
#  'Портфельный риск-аналитик (розничные риски)',
#  'Медсестра Процедурная медсестра',
#  'Exchange Administrator',
#  'руководитель группы ИТ',
#  'Специалист отдела обработки документов (ГПХ)',
#  'Слесарь сборщик, Электрогазосварщик',
#  'Руководитель отдела региональных продаж',
#  'Менеджер по приоритетным проектам (PM) - федеральные сети.',
#  'Специалист активного закупа',
#  'Финансовый директор',
#  'Товаровед. Заместитель директора.',
#  'Продавец кассир,продавец консультант',
#  'Senior dev',
#  'Кассир возвратной кассы',
#  'Осмотрщик',
#  'Senior Manager',
#  'Координатор филиала',
#  'Руководитель группы по работе с партнерами',
#  'Главный специалист отдел индивидуальных решений Управления взыскания задолженности ипотечного взыскания',
#  'СМРК',
#  'Инженер ЦТО',
#  'Менеджер агентского канала',
#  'Head of Corporate Security Division',
#  'Начальник цеха сборки комбайнов',
#  'Менеджер по компенсациям и льготам (C&B)',
#  'Руководитель группы производства b2b',
#  'Аператор Склад',
#  'Ведущий эксперт по обучению и управления карьерой',
#  'Ведущий специалист отдела по регистрации недвижимости (земельный юрист)',
#  'Специалист Товаровед',
#  'Менеджер местных закупок',
#  'Помощник прораба',
#  'HR business partner /Директор по персоналу',
#  'Руковолитель картографического отдела',
#  'Начальник отдела эксплуатации .',
#  'Ведущий кредитный эксперт Отдела кредитования малого и среднего бизнеса',
#  'ведущий специалист отдела строительства и эксплуатации гражданских объектов',
#  'Assist',
#  'специалист группы аналитики и статистики',
#  'Менеджер операционного отдела',
#  'Инженер отдела планирования и мониторинга ОП «Арктик СПГ-2. Гыдан»',
#  'Специалист отдела СИТИФОН,полная занятость.',
#  'Начальник отдела поддержки медиакомплекса',
#  '9 класс',
#  'Public relations specialist',
#  'Ведущий специалист Дирекции безопасности',
#  'Директорктор магазина',
#  'CitiGold Executive',
#  'Главный специалист Группы обслуживания корпоративных клиентов',
#  'Личный ассистент первого руководителя',
#  'Менеджер по работе с клиентами группы резерва',
#  'Старший клиенский менеджер',
#  'Заведующий хирургическим отделением',
#  'Обжигальщик ( и.о. мастера смены',
#  'Заместитель начальника управления правового обеспечения',
#  'главный специалист -инженер по ОТ',
#  'Руководитель по платформам',
#  'Главный специалист отдела банковского сопровождения',
#  'Руководитель Направления Партнёрских и Инвестиционных Ппограмм',
#  'Директор магазина (супермаркет)',
#  'Фитнес - консультант',
#  'Специалист управления контакт-центра отдел телемаркетинга',
#  'Старший менеджер по продажам B2B и B2C',
#  'Оператор единого центра поддержки продаж',
#  'Ведуший специалист',
#  'Менеджер отдела маркетинга и рекламы',
#  'Бьюти эксперт',
#  'Старший менеджер по развитию корпоративного бизнеса',
#  'Водитель безовоза',
#  'Специалист мониторинга и контроля(охрана)',
#  'Директор торгового комплекса',
#  'Financial Shared Service Delivery Senior manager',
#  'Отдел подписки',
#  'Приемосдатчик, Составитель, Диспетчер, Дежурный, Заместитель начальника станции',
#  'Руководитель службы управления транспортом Блока логистики макрорегиона Южный',
#  'Эксперт по мониторингу Департамента работы с проблемными активами',
#  'Анонимность',
#  'Коммерческий представитель по работе с ключевыми клиентами',
#  'Продуктовый тренер',
#  'Водитель узкопроходного штабелера',
#  'Начальник Управления пожарной безопасности, гражданской обороны и чрезвычайных ситуаций, охраны труда и безопасности дорожного движения (головной офис)',
#  'office support team leader',
#  'Курьер на своем авто',
#  'ведущий инженер по охране труда технического отдела службы вагонного хозяйства',
#  'Менеджер по работе с ключевыми клиентами HoReCa',
#  'Начальник отдела по подбору геолого-технических мероприятий',
#  'Продавец отдела запасных частей Fleet',
#  'Специалист по закупкам непроизводственных материалов и услуг',
#  'Специалист отдела контроля качества и профессионального развития',
#  'Директор Центра стратегического развития',
#  'Brand Managerin',
#  'Национальный менеджер по работе с каналами торговой сети',
#  'Инженер отдела по электросетевой деятельности',
#  'Руководитель продуктов',
#  'Специалист по косметике',
#  'менеджер смены 2 уровня',
#  'Backup Accountant',
#  'Старший менеджер по развитию абонентов',
#  'Бухгалтер по работе с ключевыми поставщиками',
#  'Руководитель направления, Блок эксплуатации ИТ, Корпоративный Центр',
#  'Водитель с личным грузовым автомобилем',
#  'Senior Key Account Manager',
#  'Менеджер отдела вводных уроков',
#  'Менеджер по администрированию баз данных',
#  'Специалист департамента закупок',
#  'Ведущий менеджер по работе с клиентами крупного и среднего бизнеса',
#  'Бизнес-технолог департамента продаж',
#  'Диспетчер распределительного центра',
#  'Ведущий разработчик баз данных',
#  'Директор отделения',
#  'Технолог системы управления складом',
#  'Специалист отдела розничных товаров',
#  'Главный специалист (руководитель)',
#  'Курьер , старший курьер (бригадир)',
#  'Менеджер по развитию клиентов ( менеджер по продажам )',
#  'Начальник управления по работе с проблемными активами',
#  'Аналитик по тестированию',
#  'Ведущий специалист Отдела Продаж по работе с ключевыми клиентами в республике Дагестан',
#  'Старший специалист по сервису (Администратор)',
#  'Product methodology lead',
#  'Руководитель развития ИТ-систем',
#  'Страител',
#  'Руководитель по продажам и обслуживанию',
#  'Ведущий специалист отдела экономической защиты',
#  'Рулевой-моторист',
#  'Construction engineer',
#  'Специалист по развитию и удержанию',
#  'Сотрудни ксо',
#  'Менеджер службы сервиса',
#  'Руководитель отдела персонала (HR BP)',
#  'Руководитель продаж',
#  'Руководитель направления веб-контента',
#  'Начальник Главного материального склада Забайкальской ж.д.',
#  'Менеджер по развитию продаж локальных партнеров и агентов',
#  'Спортивный консультант',
#  'Товаровед гипермаркета',
#  'Менеджер по работе  с клиентами',
#  'Администратор по обработке заказов',
#  'Машинист трубоукладчикас',
#  'Консультант по развитию региональной розничной сети',
#  'Начальник подгруппы эксплуатации зданий и сооружений',
#  'Старший специалист по работе с просроченной задолженностью',
#  'Специалист по федеральному телемаркетингу',
#  'Специалист по подготовке поставок',
#  'Товарный аналитик отдела промышленного электрооборудования Центрального предприятия',
#  'Junior System Administrator',
#  'Старший специалист группы клиентского обслуживания',
#  'Руководитель по развитию бизнеса агентского и партнерского каналов продаж',
#  'агент отдела розыска багажа',
#  'Руководитель группы торговых агентов',
#  'Специалист единого контактного центра',
#  'менеджер по работе с торговыми представителями, клиентами (супервайзер)',
#  'Оператор связи 3 класса мобильной группы',
#  'Руководитель по работе с партнерами',
#  'Директор группы больших форматов',
#  'Директор по операционной работе',
#  'MLWD Field Engineer',
#  'Водитель по доставке (офисный)',
#  'Инженер ЛСС  и АУ',
#  'Сервис менеджер по работе с холдингами',
#  'Оператор клиетского сервиса',
#  'Кочегар технологических печей',
#  'руководитель направления свежих групп товаров',
#  'Специалист по администрированию',
#  'Специалист сметно - договорного отдела',
#  'Эксперт-оценщик',
#  'POS Отдел закупок',
#  'Главный специалист-руководитель группы ГО, ЧС, МР, ЗГТ',
#  'Электромеханик сигнализации, цетрализации и блокировки',
#  'Инженер по функциональному тестированию ПО',
#  'Начальник сектора обслуживания корпоративных клиентов',
#  'специалист',
#  'Руководитель группы казначейских операций',
#  'Инженер эксплуатации радиосети',
#  'Руководитель программ развития проектной деятельности и риск-менеджмента',
#  'Автор по написанию студенческих работ',
#  'Менеджер группы телефонного взыскания',
#  'Начальник юридического управления/Советник Генерального директора по юридическим вопросам',
#  'Ведущий специалист группы аналитики отдела поддержки продаж',
#  'старший смены охраны',
#  'Кассир/выкладка товара',
#  'Специалист по мультимедиа',
#  'Торговый представитель на корпоративном автомобиле Газель',
#  'Супервайзер в отделе продаж ЗАО ******',
#  'Печатник-оформитель',
#  'оператор вт',
#  'Менеджер группы по подбору талантов',
#  'ведущий менеджер ДО Черемушки',
#  'Инженер по IT сопровождению',
#  'Специалист по сохранению  клиентов',
#  'Инженер отдела технической поддержки',
#  'Визажист MAC',
#  'Специалист отдела обслуживаниия',
#  'Оператор обработке документов',
#  'Бухгалтер отдела расчётов',
#  'Налоговый менеджер',
#  'Менеджер по поставкам',
#  'Кредитный инспектор/Менеджер сегмента КСБ',
#  'Специалист по развитию крупных корпоративных клиентов',
#  'Специалист поддержки (3-я линия поддержки сайта)',
#  'Руководитель PR',
#  'Руководитель направления штаба вице-президента Экосистемы',
#  'Технолог-конструктор торговых помещений',
#  'Менеджер по работе с корпоративными клиентами. Аналитик. Сопровождение',
#  'Начальник управления по строительству',
#  'Бригадир пути, исполняющий обязанности дорожного мастера',
#  'Главный специалист отдела эксплуатации тепловых сетей и тепловых пунктов',
#  'Инженер по буровым растворам, супервайзер',
#  'Управляющий дополнительным офисом (в состав ДО входит 3 операционных офиса)',
#  'Вице-президент Банка',
#  'Инженер по бурению (служба оперативного управления проектами)',
#  'Начальник сектора расследования обращений физических лиц',
#  'Тренинг-координатор',
#  'Специалистный специалист',
#  'Помощник заместителя Председателя Правления',
#  'Бухгалтер по учету расчетов с персоналом по оплате труда',
#  'Менеджер Центра продаж малому бизнесу и страховой агент',
#  'HR BP, Менеджер по управлению персоналом',
#  'Специалист по обеспечению каналов сбыта НоReCa',
#  'Инженер по КИП и АСУ ТП',
#  'Специалист отдела по компенсациям и льготам',
#  'CUSTOMER DEDICATED PORTFOLIO DEVELOPMENT MANAGER',
#  'Руководитель группы  Группа технического обеспечения  Служба эксплуатации.  Федеральный Распределительный Центр',
#  'Специалист ручного тестирования',
#  'Бригадир. Монтажник тт 6 разряд',
#  'и.о. администратора, кассир, продавец',
#  'Менеджер по HR-эффективности (Аналитик)',
#  'Специалист отдела внедрения и сопровождения ПО',
#  'Специалист технической поддержки 2-ой категории',
#  'Слесарь по КИПИА 4-разряд.',
#  'Менеджер по привлечению юридических лиц и индивидуальных предпринимателей на расчетно-кассовое обслуживание',
#  'Химик-биолог',
#  'Менеджер по персоналу(ведение КДП в полном объёме, подбор персонала)',
#  'Токарь ЧПУ',
#  'Электромонтёр + оператор газовых котельных',
#  'Приемосдатчик груза и багажа, Бригадир смены, и.о. Нач. Склада,',
#  'Менеджер смены пиццерии',
#  'Заместитель руководителя отделения по обслуживанию вип-клиентов',
#  'ИТ- специалист',
#  'Менеджер по продажам, старший специалист по обслуживанию',
#  'Старший менеджер по развитию розничного бизнеса',
#  'Менеджер интернет-проекта',
#  'Ведущий специалист ФГ продаж IT решений',
#  'Инкогнито',
#  'Специалист по сопровождению зарплатных клиентов',
#  'Руководитель проектов департамента  "Системная интеграция и Технологический консалтинг"',
#  'Менеджер по совершенствованию производственного процесса',
#  'Оператор Пэк',
#  'Оператор при ДСП, дежурный по парку, дежурный по станции, инженер отдела по работе со станциями',
#  'Специалист по работе с внутренними клиентами',
#  'Ведущий эксперт по технологиям',
#  'Ведущий специалист отдела управления персоналом дирекции',
#  'Ведущий специалист по разработке ПО',
#  'Руководитель группы торговых представителей в канале современной торговли',
#  'Элетромантер',
#  'Дежурный помощник начальника',
#  'Руководитель отдела продаж HoReCa',
#  'Инспектор ОТО ЦКП',
#  'Продавец-консультант в зоомагазине',
#  'Техник-геодезист',
#  'Сборщик - Сортировщик',
#  'Технический переводчик',
#  'Специалист по МСФО',
#  'Механик по эксплуатации транспортных средств на проекте FGP ТОО "Тенгизшевройл"',
#  'Access Manager',
#  'Менеджер складской службы',
#  'Ассистент юридического отдела',
#  'Ведущий инженер по организации управления производством',
#  'Региональный менеджер по качеству',
#  'От руководителя строительных проектов до Директора по строительству',
#  'Оперативный менеджер  собственных пунктов выдачи заказов',
#  'Customer Services Assistant',
#  'Консультант бренда ysl',
#  'Директор вагона ресторана',
#  'Директор филиала в Хабаровском крае',
#  'Руководитель территории B2c',
#  'Senior Brand manager',
#  'Fluid Analysis Specialist',
#  'Инженер по сопровождению POS терминалов',
#  'Специалист по качеству и производственному контролю',
#  'Операционный директор сети',
#  'Главный специалист по поддержке продаж торгового эквайринга',
#  'Менеджер по развитию экспресс доставки и самовывоза',
#  'Старший специалист в отделе кредитования',
#  'Приёмосдатчик гк',
#  'Кладовщик материального склада',
#  'Финансовый аналитик по планированию производственных затрат',
#  'Ведущий инженер ИТ',
#  'Контролер холодно-штамповочных работ',
#  'Главный специалист отдела эксплуатации',
#  'Аналитик кадрового производства',
#  'Руководитель направления автоматизированных методов аудита отдела аудита основных бизнес-процессов',
#  'Машинист технологических компрессоров 5 го разряда',
#  'Специалист группы обслуживания и сопровождения корпоративных клиентов',
#  'Менеджер по персоналу -> Старший менеджер по персоналу',
#  'Junior manager',
#  'Кредитный инспектор управления верификации и предупреждения задолженности департамента рисков',
#  'Водитель автомобиля легкового',
#  'Специалист по работе с массовым персоналом',
#  'Автоматчик',
#  'Специалист приемного отдела/ товаровед',
#  'Грузовой диспетчер(логист), приёмосдатчик груза',
#  'Заместитель начальника управления по работе с ПАО «НК «Роснефть»',
#  'Специалист по администрированию серверов',
#  'Начальник трамвайного депо им. Русакова',
#  'Заместитель руководителя Блока по работе с топливно-энергетическим комплексом',
#  'Специалист-универсал входящей линии',
#  'в',
#  'Супервайзер.',
#  'Менеджер по продажам автомобилей Toyota',
#  'Ведущий инженер по планированию ремонтов',
#  'Укладчик товара',
#  'Junior Brand Manager',
#  'Координатор по поддержке коммерческой функции',
#  'Руководитель направления по продажам эквайринга и комиссионных продуктов',
#  'Директор регионального центра "Московия"',
#  'Активный менеджер',
#  'Analyst-Monthly Intern',
#  'Менеджер по закупу (РФ)',
#  'Менеджер по работе с клиентами/ Администратор салона',
#  'Дизайнер продукта',
#  'Технический дизайнер',
#  'Старший консультант актуарной группы',
#  'Специалист по работе с партнерами ТД "******"',
#  'Заместитель начальника отдела выездных проверок',
#  'Старший специалист отдела товародвижения',
#  'Водитель категории BCD',
#  'Электромеханик по измерениям и испытаниям 6 разряда',
#  'Специалист по акциям программ лояльности',
#  'Руководитель коммерческого отдела/ Руководитель проектной группы',
#  'Специалист по работе с юр лицами',
#  'Менеджер / Руководитель направления',
#  'Solution Arhitect',
#  'Программист-тестировщик',
#  'Помощник менеджера по персоналу, ресёчер',
#  'Руководитель федерального проекта',
#  'Старший менеджер по оптимизации сети радиодоступа',
#  'Продавец уневерсал',
#  'Электромонтер по ремонту вл',
#  'Ночной водитель-курьер',
#  'Крелитгый специалист',
#  'Специалист по поддержке процессов управления персоналом',
#  'ведущий специалист телефонной верификации',
#  'Електрогазо сварщик',
#  'Руководитель направления малого и среднего бизнеса',
#  'Кладовщик, старший исходного потока',
#  'Управляющий суши баром',
#  'Бригадир газорезчик 5 разряд',
#  'Экспедитор 2 класса',
#  'Менеджер курьерской выдачи,кладовщик',
#  'Менеджер торгового лала',
#  'Торговый представитель MacCoffee',
#  'Курир',
#  'Юрисконсульт группы корпоративных отношений',
#  'Слесарь по обслуживанию металлоконструкций',
#  'Руководитель службы кредитования (board-1)',
#  'мкм',
#  'Regular Test Engineer',
#  'Инженер по охране труда и пожарной безопасности',
#  'Специалист транспортной функции',
#  ...}

# %%
stratified_train = stratify_data(
    df_data=train, stratify_column_name=STRATIFY_COL,
    stratify_values=stratify_values,
    stratify_proportions=stratify_proportions)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_27023/4172004646.py in <module>
# ----> 1 stratified_train = stratify_data(
#       2     df_data=train, stratify_column_name=STRATIFY_COL,
#       3     stratify_values=stratify_values,
#       4     stratify_proportions=stratify_proportions)
#
# /tmp/ipykernel_27023/2692356419.py in stratify_data(df_data, stratify_column_name, stratify_values, stratify_proportions, random_state)
#      21
#      22         df_filtered = df_data[df_data[stratify_column_name] ==stratify_values[i]] # Filter the source data based on the currently selected stratify value
# ---> 23         df_temp = df_filtered.sample(replace=True, n=ratio_len, random_state=random_state) # Sample the filtered data using the calculated ratio
#      24
#      25         df_stratified = pd.concat([df_stratified, df_temp]) # Add the sampled / stratified datasets together to produce the final result
#
# ~/miniconda3/lib/python3.9/site-packages/pandas/core/generic.py in sample(self, n, frac, replace, weights, random_state, axis, ignore_index)
#    5363             )
#    5364
# -> 5365         locs = rs.choice(axis_length, size=n, replace=replace, p=weights)
#    5366         result = self.take(locs, axis=axis)
#    5367         if ignore_index:
#
# mtrand.pyx in numpy.random.mtrand.RandomState.choice()
#
# ValueError: a must be greater than 0 unless no samples are taken

# %%
for col in ORDERED_CATEGORIES + UNORDERED_CATEGORIES:
    f_obs = train[col].value_counts() / len(train)
    f_exp = test[col].value_counts() / len(test)
    common_idx = f_obs.index.intersection(f_exp.index)
    chisq, p_value = chisquare(f_obs=f_obs.loc[common_idx], f_exp=f_exp.loc[common_idx], ddof=1)
    print(col, 'chisq:', chisq, 'p_value:', p_value)
# Out:
# salary_rating chisq: 0.016009001456495645 p_value: 0.9994638573693502
# team_rating chisq: 0.0007473694718391948 p_value: 0.9999945671906315
# managment_rating chisq: 0.0032187373775179836 p_value: 0.9999514792174871
# career_rating chisq: 0.01020243840127024 p_value: 0.9999870329455216
# workplace_rating chisq: 0.0011174173900297376 p_value: 0.9999900689226666
# rest_recovery_rating chisq: 0.00993272797025919 p_value: 0.9997375008704167
# city chisq: inf p_value: 0.0
# position chisq: inf p_value: 0.0
# /home/as/miniconda3/lib/python3.9/site-packages/scipy/stats/stats.py:6707: RuntimeWarning: divide by zero encountered in true_divide
#   terms = (f_obs_float - f_exp)**2 / f_exp

# %%
for col in ORDERED_CATEGORIES + UNORDERED_CATEGORIES:
    f_obs = train[col].value_counts() / len(train)
    f_exp = test[col].value_counts() / len(test)
    common_idx = f_obs.index.intersection(f_exp.index)
    chisq, p_value = ks_2samp(data1=f_obs.loc[common_idx], data2=f_exp.loc[common_idx])
    print(col, 'chisq:', chisq, 'p_value:', p_value)
# Out:
# salary_rating chisq: 0.4 p_value: 0.873015873015873
# team_rating chisq: 0.2 p_value: 1.0
# managment_rating chisq: 0.2 p_value: 1.0
# career_rating chisq: 0.16666666666666666 p_value: 0.9999999999999998
# workplace_rating chisq: 0.4 p_value: 0.873015873015873
# rest_recovery_rating chisq: 0.2 p_value: 1.0
# city chisq: 0.28844404003639673 p_value: 1.095385563738221e-40
# position chisq: 0.48718523165158173 p_value: 0.0

# %%
for col in ORDERED_CATEGORIES + UNORDERED_CATEGORIES:
    f_obs = np.array([1,1,1,1,1,1,1])
    f_obs = f_obs / np.sum(f_obs)
    f_exp =  np.array([1,1,1,1,1,1,1])
    f_exp = f_exp / np.sum(f_exp)
    chisq, p_value = chisquare(f_obs=f_obs, f_exp=f_exp, ddof=1)
    print(col, 'chisq:', chisq, 'p_value:', p_value)
# Out:
# salary_rating chisq: 0.0 p_value: 1.0
# team_rating chisq: 0.0 p_value: 1.0
# managment_rating chisq: 0.0 p_value: 1.0
# career_rating chisq: 0.0 p_value: 1.0
# workplace_rating chisq: 0.0 p_value: 1.0
# rest_recovery_rating chisq: 0.0 p_value: 1.0
# city chisq: 0.0 p_value: 1.0
# position chisq: 0.0 p_value: 1.0

# %%
1e-08
# Out:
# 1e-08

# %%
a = train[ORDERED_CATEGORIES[0]].value_counts()
b = test[ORDERED_CATEGORIES[0]].value_counts()

# %%
a.index.intersection(b.index)
# Out:
# CategoricalIndex([5, 4, 3, 1, 2], categories=[1, 2, 3, 4, 5], ordered=True, dtype='category')

# %%
len(stratified_train)
# Out:
# 50876

# %%
len(train)
# Out:
# 50876
